# %% [markdown]
# ## Plot tracking results

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
# load data:
with open('track.json', 'r') as f:
     track = json.load(f)

# %%
track.keys()
# Out:
# dict_keys(['turns', 'zeta', 'x', 'y', 'delta', 'p0c', 'pID', 'state'])

# %%
np.shape(track['zeta'])
# Out:
# (11, 6000)

# %%
turns  = np.array(track['turns'])
zeta  = np.array(track['zeta'])
x  = np.array(track['x'])
y  = np.array(track['y'])
delta = np.array(track['delta'])
p0c   = np.array(track['p0c'])
pID   = np.array(track['pID'])
#parent_pID = np.array(track['parent_pID'])
state = np.array(track['state'])

# %%
#pID

# %%
#p0c

# %%
#parent_pID

# %%
#state

# %%
plt.figure(dpi=150)

plt.subplot(2,1,1)

N_saves = len(zeta)

save = 0
plt.scatter(100*zeta[save],100*delta[save],
            label='turn %g' % turns[save], s=1, alpha=0.1)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$\Delta p/p$ (%)')

plt.grid()
plt.xlim(-30,+30)
plt.ylim(-0.1,+0.1)
plt.title(f'Turn {turns[save]}')

#save = int(N_saves/2)
#plt.scatter(100*zeta[save],100*delta[save], label='turn %g' % turns[save], s=1)

plt.subplot(2,1,2)

save = -1
plt.scatter(100*zeta[save],100*delta[save],
            label='turn %g' % turns[save], s=1, alpha=0.1)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$\Delta p/p$ (%)')

plt.grid()
plt.xlim(-30,+30)
plt.ylim(-0.1,+0.1)
plt.title(f'Turn {turns[save]}')

#plt.savefig('image.png')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Excited ions:

# %%
plt.figure(dpi=100)
plt.grid()

save = -1

z = zeta[save]*100; dp = delta[save]*100; excited = (state[save] == 2)
plt.scatter(z,dp, label='Still', s=2, alpha=0.1)
plt.scatter(z[excited],dp[excited], label='Excited', s=3, c='black', alpha=0.3)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$\Delta p/p$ (%)')

plt.legend()
plt.ylim(-0.1,+0.1)

title = "%.1f %% of ions excited" % (100.0*len(z[excited])/len(z))
plt.title(title)

#plt.savefig('image.png')
plt.show()

# %%
plt.figure(dpi=100)
plt.grid()

z = zeta[save]*100; y_mm = y[save]*1e3; excited = (state[save] == 2)
plt.scatter(z,y_mm, label='Still', s=2, alpha=0.1)
plt.scatter(z[excited],y_mm[excited], label='Excited', s=3, c='black', alpha=0.3)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$y$ (mm)')

plt.legend()
plt.title(title)
#plt.ylim(-0.1,+0.1)

#plt.savefig('image.png')
plt.show()

# %%
plt.figure(dpi=100)
plt.grid()

z = zeta[save]*100; x_mm = x[save]*1e3; excited = (state[save] == 2)
plt.scatter(z,x_mm, label='Still', s=2, alpha=0.1)
plt.scatter(z[excited],x_mm[excited], label='Excited', s=3, c='black', alpha=0.3)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$x$ (mm)')

plt.legend()
plt.title(title)
#plt.ylim(-0.1,+0.1)

#plt.savefig('image.png')
plt.show()

# %%
plt.figure(dpi=100)
plt.grid()

pid = 1
plt.scatter(100*zeta[:,pid], 100*delta[:,pid], label='particle %g' % pid, s=2)

pid = 6
plt.scatter(100*zeta[:,pid], 100*delta[:,pid], label='particle %g' % pid, s=2)

plt.xlabel(r'$\zeta$ (cm)')
plt.ylabel(r'$\Delta p/p$ (%)')

plt.ylim(-0.1,+0.1)
plt.legend()

#plt.savefig('image.png')
plt.show()

# %%
plt.figure(dpi=100)
plt.grid()

pid = 1
plt.scatter(turns, 100*delta[:,pid], label='particle %g' % pid, s=2)

pid = 6
plt.scatter(turns, 100*delta[:,pid], label='particle %g' % pid, s=2)

plt.xlabel('Turn')
plt.ylabel(r'$\Delta p/p$ (%)')

plt.ylim(-0.1,+0.1)
plt.legend()

#plt.savefig('image.png')
plt.show()

# %%
pwd
# Out:
# '/home/petrenko/soft/Xsuite/xtrack/examples/gamma_factory'

# %%
ls -all -h
# Out:
# total 16M
# drwxrwxr-x  4 petrenko binp 4.0K Nov 13 05:04 ./
# drwxrwxr-x 12 petrenko binp 4.0K Oct 22 00:04 ../
# -rw-rw-r--  1 petrenko binp 7.8K Nov 13 04:57 000_gamma_factory_PoP_cooling.py
# -rw-rw-r--  1 petrenko binp 7.8K Nov 13 05:00 000_gamma_factory_PoP.py
# drwxrwxr-x  2 petrenko binp 4.0K Nov 13 05:00 .ipynb_checkpoints/
# drwxrwxr-x  3 petrenko binp 4.0K Nov 12 21:53 mpi_test/
# -rw-rw-r--  1 petrenko binp 1.1M Nov 13 05:05 plot_tracking.html
# -rw-rw-r--  1 petrenko binp 482K Nov 13 05:04 plot_tracking.ipynb
# -rw-rw-r--  1 petrenko binp 5.1M Nov 12 22:40 tmp_test.ipynb
# -rw-rw-r--  1 petrenko binp 8.8M Nov 13 05:04 track.json

# %%
# !jupyter nbconvert --to HTML plot_tracking.ipynb
# Out:
# [NbConvertApp] Converting notebook plot_tracking.ipynb to HTML
# [NbConvertApp] Writing 1087785 bytes to plot_tracking.html
